# %% [markdown]
# <a href="https://colab.research.google.com/github/RashmiNawoda/RashmiNawoda/blob/main/simple%20neural%20network%20for%20add%20two%20number%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # simple neural network that adds 2 numbers
#
# import random
# import numpy as np
#
#
# ---
#
#
#
#
# x =[]
# y =[]
# for i in range (1000):
#     x.append ([random.randint(1,1000),random.randint(1,100),random.randint(1,1000)])
#     y.append(sum(x[i]))
#
#
# x=np.array(x)
# y=np.array(y).reshape(-1,1)
#
# #network part
# from keras.modals import Sequential
# from  keras.layers import Dense, Dropout
#
# model1 = Sequenial()
# model1.add(Dense(output_dim=6,activation='relu',input_dim=2))
# model1.add(Dense(output_dim=12,activation='relu'))
# model1.add(Dense(output_dim=12,activation='relu'))
# model1.add(Dense(output_dim=6,activation='relu'))
# model1.add(Dense(output_dim=1,activation='linear'))
#
# model1.compile('adam','mean_squard_error')
# model1.fit(x,y,epoches=200)
#
# pred = np.array([[12.0,25.5]])
# predd= model.predict(pred)
#
#
#
# """
# this is a python code for neural network add two integer or two floating number.
# firstly use random and numpy libraries in code for x , y list convert to the array.
# collecting data is first part is that is that random python library use and range (1 to 1000). use for loop up to 1000 value.
# x append in 1000 rows and y append 2 list.
# """
